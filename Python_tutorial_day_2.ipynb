# %% [markdown]
# # Analyzing Data from Multiple Files

# %% [markdown]
# The Python library **glob** allows you to find files and directories whose names match a pattern

# %%
import glob

# %%
ls
# Out:
# Python_tutorial_day_1.ipynb  inflammation-08.csv
# Untitled.ipynb               inflammation-09.csv
# inflammation-01.csv          inflammation-10.csv
# inflammation-02.csv          inflammation-11.csv
# inflammation-03.csv          inflammation-12.csv
# inflammation-04.csv          small-01.csv
# inflammation-05.csv          small-02.csv
# inflammation-06.csv          small-03.csv
# inflammation-07.csv

# %%
# %matplotlib inline # the magic function that makes sure your figures are plotted in the notebook

# %%
print(glob.glob("inflammation*.csv")) # Find files with the name inflammation in our current working directory
# Out:
# ['inflammation-01.csv', 'inflammation-02.csv', 'inflammation-03.csv', 'inflammation-04.csv', 'inflammation-05.csv', 'inflammation-06.csv', 'inflammation-07.csv', 'inflammation-08.csv', 'inflammation-09.csv', 'inflammation-10.csv', 'inflammation-11.csv', 'inflammation-12.csv']

# %%
import numpy
import matplotlib.pyplot
import glob

filenames = sorted(glob.glob('inflammation*.csv')) # Find the files and sort them
filenames = filenames[0:5] # Select the first five files

for f in filenames:
    print(f)
    
    data = numpy.loadtxt(fname=f, delimiter=",")
    
    fig = matplotlib.pyplot.figure(figsize=(10.0,3.0))
    
    axes1 = fig.add_subplot(1,3,1)
    axes2 = fig.add_subplot(1,3,2)
    axes3 = fig.add_subplot(1,3,3)
    
    axes1.set_ylabel("average")
    axes1.plot(numpy.mean(data, axis=0))
    
    axes2.set_ylabel('max')
    axes2.plot(numpy.max(data, axis=0))
    
    axes3.set_ylabel("min")
    axes3.plot(numpy.min(data, axis=0))
    
    fig.tight_layout()
    matplotlib.pyplot.show()
# Out:
# inflammation-01.csv
# inflammation-02.csv
# inflammation-03.csv
# inflammation-04.csv
# inflammation-05.csv

# %% [markdown]
# Plot the difference between the average of the first dataset and the average of the second dataset, i.e., the difference between the leftmost plot of the first two figures.

# %%
import glob
import numpy
import matplotlib.pyplot

filenames = sorted(glob.glob('inflammation*.csv'))

data0 = numpy.loadtxt(fname=filenames[0], delimiter=',')
data1 = numpy.loadtxt(fname=filenames[1], delimiter=',')

#fig = matplotlib.pyplot.figure()

matplotlib.pyplot.ylabel("Difference in average")
matplotlib.pyplot.plot(numpy.mean(data0, axis=0) - numpy.mean(data1, axis=0))

fig.tight_layout()
matplotlib.pyplot.show()

# %% [markdown]
# # Making Choices

# %% [markdown]
# ###  Conditionals

# %% [markdown]
# if num > 100:
#     print('greater')
#     print('done')
# else:
#     print('not greater')

# %%
num = 53
print('before conditional...')
if num > 100:
    print(num, 'is greater than 100')
print('after conditional')
# Out:
# before conditional...
# after conditional

# %%
num = -3
if num > 0:
    print(num, 'is positive')
elif num == 0:
    print(num, 'is zero')

# %%
if (1 > 0) and (-1 > 0):
    print('both parts are true')
else:
    print('at least one part is false')
# Out:
# at least one part is false

# %%
if (1 < 0) or (-1 < 0):
    print('at least one of these is true')
# Out:
# at least one of these is true

# %% [markdown]
# ###  Checking our Data

# %%
import numpy

# %%
max_inflammation_0 = numpy.max(data, axis=0)[0]
max_inflammation_20 = numpy.max(data, axis=0)[20]

# %%
data = numpy.loadtxt(fname='inflammation-02.csv', delimiter=',')

# %%
max_inflammation_0 = numpy.max(data, axis=0)[0]
max_inflammation_20 = numpy.max(data, axis=0)[20]

# %%
if max_inflammation_0 == 0 and max_inflammation_20 == 20:
    print('Suspicious looking maxima!')
# Out:
# Suspicious looking maxima!

# %%
if numpy.sum(numpy.min(data, axis=0))==0:
    print('minima add up to zero')

# %%
if 4 > 5:
    print('A')
elif 4 == 5:
    print('B')
elif 4 < 5:
    print('C')
# Out:
# C

# %%
x = -1
x *= 5
x = x * 5
print(x)
# Out:
# 4

# %% [markdown]
# 1. Write a loop that counts the number of vowels in a character string
# 2. Test it on a few individual words and full sentences

# %%
vowels = (1,2,3,4,5,6)
sentence = 'Mary had a little lamb'
count = 0

for char in sentence:
    if char in vowels:
        count = count + 1
        
print('There are', count, 'vowels')
# Out:
# There are 6 vowels

# %%
# = is for assignment

weight = 100

# == for 'is equivalent to

3 == 3
# Out:
# True

# %%
print(weight)
# Out:
# 100

# %% [markdown]
# # Creating Functions

# %% [markdown]
#  Defining a function fahr_to_celsius that converts temperatures from Fahrenheit to Celsius:

# %%
def fahr_to_celsius(temp):
    temp_c = (temp -32) * (5/9)
    return temp_c

# %% [markdown]
# The function definition opens with the keyword def followed by the name of the function (fahr_to_celsius) and a parenthesized list of parameter names (temp). The body of the function — the statements that are executed when it runs — is indented below the definition line. The body concludes with a return keyword followed by the return value.

# %%
fahr_to_celsius(32)
# Out:
# 0.0

# %%
fahr_to_celsius(126)
# Out:
# 52.22222222222222

# %%
print("The temperature for water in celsius", fahr_to_celsius(32), 'celsius')
# Out:
# The temperature for water in celsius 0.0 celsius

# %%
fahr_to_celsius(32)
# Out:
# the temperature in celsius 0.0 celsius

# %%
fahr_to_celsius(100)
# Out:
# 37.77777777777778

# %% [markdown]
# ### Composing Functions

# %% [markdown]
# A function that turns Celsius into Kelvin

# %%
def celsius_to_kelvin(temp_c):
    return temp_c + 273.15

# %%
print("freezing point of water in Kelvin", celsius_to_kelvin(0.))
# Out:
# freezing point of water in Kelvin 273.15

# %%
print("freezing point of water in Kelvin", celsius_to_kelvin(30.0))
# Out:
# freezing point of water in Kelvin 303.15

# %% [markdown]
# A function that turns temperature from Fahrenheit into Kelvin

# %%
def fahr_to_kelvin(temp_f):
    temp_c = fahr_to_celsius(temp_f)
    temp_k = celsius_to_kelvin(temp_c)
    return temp_k

# %%
print("boiling point of water in Kelvin:", fahr_to_kelvin(212.0))
# Out:
# boiling point of water in Kelvin: 373.15

# %% [markdown]
# Function to add two numbers

# %%
def add(a,b):
    result = a +b
    return result

# %%
add(2,5)
# Out:
# 7

# %%
add(100,200)
# Out:
# 300

# %%
numpy.sum((2,3))
# Out:
# 5

# %% [markdown]
# If the variable s refers to a string, then s[0] is the string’s first character and s[-1] is its last. Write a function called outer that returns a string made up of just the first and last characters of its input. A call to your function should look like this:

# %%
# print(outer(helium))
# hm

def outer(string):
    result = string[0] + string[-1]
    return result

# %%
print(outer("helium"))
# Out:
# hm

# %%
print(outer("hydrogen"))
# Out:
# hn

# %%
outer("oxygen")
# Out:
# 'on'

# %% [markdown]
# ### Tidying up

# %% [markdown]
# First, let’s make an **analyze** function that generates our plots:

# %%
def analyze(filename):
    
    data = numpy.loadtxt(fname=filename, delimiter=",")
    
    fig = matplotlib.pyplot.figure(figsize=(10.0,3.0))
    
    axes1 = fig.add_subplot(1,3,1)
    axes2 = fig.add_subplot(1,3,2)
    axes3 = fig.add_subplot(1,3,3)
    
    axes1.set_ylabel("average")
    axes1.plot(numpy.mean(data, axis=0))
    
    axes2.set_ylabel('max')
    axes2.plot(numpy.max(data, axis=0))
    
    axes3.set_ylabel("min")
    axes3.plot(numpy.min(data, axis=0))
    
    fig.tight_layout()
    matplotlib.pyplot.show()

# %% [markdown]
# Another function called **detect_problems** that checks for those systematics we noticed:

# %%
def detect_problems(filename):
    
    data = numpy.loadtxt(fname=filename, delimiter=",")
    
    if numpy.max(data, axis=0)[0] == 0 and numpy.max(data, axis=0)[20] == 20:
        print("Suspicious looking maxima")
    elif numpy.sum(numpy.min(data, axis=0)) == 0:
        print("Minima add up to zero")
    else:
        print("seems ok!")

# %% [markdown]
# We can reproduce the previous analysis with a much simpler **for loop**:

# %%
filenames = sorted(glob.glob("inflammation*.csv"))

for f in filenames[5:7]:
    print(f)
    analyze(f)
    detect_problems(f)
# Out:
# inflammation-06.csv
# Suspicious looking maxima
# inflammation-07.csv
# Suspicious looking maxima
